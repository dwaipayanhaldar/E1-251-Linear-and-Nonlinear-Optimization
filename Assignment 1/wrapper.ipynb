# %%
import skimage
from skimage.util import img_as_float

from src import *

# %%
cameraman = img_as_float(skimage.io.imread("images/cameraman.tif"))

reconstructed_cameraman_02 = reconstruct(cameraman, 0.2)
reconstructed_cameraman_03 = reconstruct(cameraman, 0.3)
reconstructed_cameraman_05 = reconstruct(cameraman, 0.5)

# %%
lena = img_as_float(skimage.io.imread("images/lena256.pgm"))

# reconstructed_lena_02 = reconstruct(lena, 0.2)
reconstructed_lena_03 = reconstruct(lena, 0.3)
reconstructed_lena_05 = reconstruct(lena, 0.5)
# Out:
# One lambda completed...
# One lambda completed...
# One lambda completed...
# One lambda completed...
# One lambda completed...
# Best lambda for p = 0.3 is 0.1
# PSNR for that best lambda = 0.1 and p = 0.3 is 66.77439587702203
# Runtime for that best lambda = 0.1 and p = 0.3 is 15.194970846176147
# One lambda completed...
# One lambda completed...
# One lambda completed...
# One lambda completed...
# One lambda completed...
# Best lambda for p = 0.4 is 0.01
# PSNR for that best lambda = 0.01 and p = 0.4 is 67.49635856925374
# Runtime for that best lambda = 0.01 and p = 0.4 is 41.22244310379028
# One lambda completed...
# One lambda completed...
# One lambda completed...
# One lambda completed...
# One lambda completed...
# Best lambda for p = 0.5 is 0.01
# PSNR for that best lambda = 0.01 and p = 0.5 is 68.0261861682231
# Runtime for that best lambda = 0.01 and p = 0.5 is 5.940907001495361
# Total runtime for one r: 361.74886107444763
# One lambda completed...
# ...
